# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../Data/trekkers_df.csv")

# %%
df.head()
# Out:
#                     Email-ID                      Name  Height  Weight  Age  \
# 0      lilianelangern@gmx.de           Violetta Täsche     178      81   28
# 1       schmidtramona@aol.de  Herr Hans-Albert Mangold     167      81   30
# 2    benediktadler@gmail.com          Martha Kuhl B.A.     164      68   29
# 3           zkade@hotmail.de       Erich Sorgatz B.Sc.     172      73   32
# 4  bonbachraphaela@klemt.com          Karl-Otto Dippel     196     102   25
#
#   Gender    City    Locality                     Languages college  \
# 0      M  Nashik       Ambad                   ['Marathi']   PCCOE
# 1   None  Mumbai      Bandra  ['Urdu', 'Marathi', 'Hindi']   PCCOE
# 2      M  Nashik  Panchavati           ['Bengali', 'Urdu']    PICT
# 3      F  Mumbai      Bandra                   ['English']    PICT
# 4   None    Pune    Nal Stop                   ['Bengali']   PCCOE
#
#           Profession Have you gone Trekking  \
# 0             Lawyer                      Y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Email-ID                10000 non-null  object
#  1   Name                    10000 non-null  object
#  2   Height                  10000 non-null  int64
#  3   Weight                  10000 non-null  int64
#  4   Age                     10000 non-null  int64
#  5   Gender                  10000 non-null  object
#  6   City                    10000 non-null  object
#  7   Locality                10000 non-null  object
#  8   Languages               10000 non-null  object
#  9   college                 10000 non-null  object
#  10  Profession              10000 non-null  object
#  11  Have you gone Trekking  10000 non-null  object
#  12  Preferred Days          10000 non-null  object
#  13  Number of Treks         10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#              Height        Weight           Age  Number of Treks
# count  10000.000000  10000.000000  10000.000000     10000.000000
# mean     179.615500     80.240000     29.721900         1.262200
# std       11.545856     17.531621      9.359355         1.453706
# min      160.000000     50.000000     10.000000         0.000000
# 25%      170.000000     65.000000     23.000000         0.000000
# 50%      180.000000     80.000000     29.000000         0.000000
# 75%      190.000000     95.000000     36.000000         2.000000
# max      199.000000    110.000000     68.000000         6.000000

# %%
# plot pie chart for occupation
df['Profession'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Profession'>
